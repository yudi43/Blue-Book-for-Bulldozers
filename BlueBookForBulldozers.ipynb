# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
from fastai.imports import *
from fastai.structured import *

from pandas_summary import DataFrameSummary
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from IPython.display import display

from sklearn import metrics

# %%
PATH = "data/"

# %%
# !ls {PATH}
# Out:
# Train.csv

# %%
df_raw = pd.read_csv(f'{PATH}Train.csv', low_memory=False, 
                     parse_dates=["saledate"])

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 335000 entries, 0 to 334999
# Data columns (total 54 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Unnamed: 0                335000 non-null  int64
#  1   SalesID                   335000 non-null  int64
#  2   SalePrice                 335000 non-null  int64
#  3   MachineID                 335000 non-null  int64
#  4   ModelID                   335000 non-null  int64
#  5   datasource                335000 non-null  int64
#  6   auctioneerID              322558 non-null  float64
#  7   YearMade                  335000 non-null  int64
#  8   MachineHoursCurrentMeter  85425 non-null   float64
#  9   UsageBand                 41641 non-null   object
#  10  saledate                  335000 non-null  datetime64[ns]
#  11  fiModelDesc               335000 non-null  object
#  12  fiBaseModel               335000 non-null  object
#  13  fiSecondaryDesc           220781 non-null  object
#  14  fiModelSeries             42519 non-null   object
#  15  fiModelDescriptor         56229 non-null   object
#  16  ProductSize               159378 non-null  object
#  17  fiProductClassDesc        335000 non-null  object
#  18  state                     335000 non-null  object
#  19  ProductGroup              335000 non-null  object
#  20  ProductGroupDesc          335000 non-null  object
#  21  Drive_System              88917 non-null   object
#  22  Enclosure                 334729 non-null  object
#  23  Forks                     159498 non-null  object
#  24  Pad_Type                  66800 non-null   object
#  25  Ride_Control              125194 non-null  object
#  26  Stick                     66800 non-null   object
#  27  Transmission              155249 non-null  object
#  28  Turbocharged              66800 non-null   object
#  29  Blade_Extension           22110 non-null   object
#  30  Blade_Width               22110 non-null   object
#  31  Enclosure_Type            22110 non-null   object
#  32  Engine_Horsepower         22110 non-null   object
#  33  Hydraulics                267053 non-null  object
#  34  Pushblock                 22110 non-null   object
#  35  Ripper                    88503 non-null   object
#  36  Scarifier                 22120 non-null   object
#  37  Tip_Control               22110 non-null   object
#  38  Tire_Size                 80515 non-null   object
#  39  Coupler                   176401 non-null  object
#  40  Coupler_System            34318 non-null   object
#  41  Grouser_Tracks            34233 non-null   object
#  42  Hydraulics_Flow           34233 non-null   object
#  43  Track_Type                82162 non-null   object
#  44  Undercarriage_Pad_Width   82758 non-null   object
#  45  Stick_Length              82218 non-null   object
#  46  Thumb                     82267 non-null   object
#  47  Pattern_Changer           82218 non-null   object
#  48  Grouser_Type              82162 non-null   object
#  49  Backhoe_Mounting          66181 non-null   object
#  50  Blade_Type                67213 non-null   object
#  51  Travel_Controls           67211 non-null   object
#  52  Differential_Type         58341 non-null   object
#  53  Steering_Controls         58306 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(7), object(44)
# memory usage: 138.0+ MB

# %%
def display_all(df):
    with pd.option_context('display.max_rows', 1000):
        with pd.option_context('display.max_rows', 1000):
            display(df)

# %%
display_all(df_raw.tail().transpose())
# Out:
#                                                                      334995  \
# Unnamed: 0                                                           334995
# SalesID                                                             2348158
# SalePrice                                                             13000
# MachineID                                                           1766236
# ModelID                                                                4603
# datasource                                                              136
# auctioneerID                                                            NaN
# YearMade                                                               1994
# MachineHoursCurrentMeter                                                  0
# UsageBand                                                               NaN
# saledate                                                2009-11-06 00:00:00
# fiModelDesc                                                            310D
# fiBaseModel                                                             310
# fiSecondaryDesc                                                           D
# fiModelSeries                                                           NaN
# fiModelDescriptor                                                       NaN
# ProductSize                                                             NaN
# fiProductClassDesc        Backhoe Loader - 14.0 to 15.0 Ft Standard Digg...
# state                                                                Nevada
# ProductGroup                                                             BL
# ProductGroupDesc                                            Backhoe Loaders
# Drive_System                                                Two Wheel Drive
# Enclosure                                                             OROPS
# Forks                                                   None or Unspecified
# Pad_Type                                                None or Unspecified
# Ride_Control                                                             No
# Stick                                                              Extended
# Transmission                                                       Standard
# Turbocharged                                            None or Unspecified
# Blade_Extension                                                         NaN
# Blade_Width                                                             NaN
# Enclosure_Type                                                          NaN
# Engine_Horsepower                                                       NaN
# Hydraulics                                                              NaN
# Pushblock                                                               NaN
# Ripper                                                                  NaN
# Scarifier                                                               NaN
# Tip_Control                                                             NaN
# Tire_Size                                                               NaN
# Coupler                                                                 NaN
# Coupler_System                                                          NaN
# Grouser_Tracks                                                          NaN
# Hydraulics_Flow                                                         NaN
# Track_Type                                                              NaN
# Undercarriage_Pad_Width                                                 NaN
# Stick_Length                                                            NaN
# Thumb                                                                   NaN
# Pattern_Changer                                                         NaN
# Grouser_Type                                                            NaN
# Backhoe_Mounting                                                        NaN
# Blade_Type                                                              NaN
# Travel_Controls                                                         NaN
# Differential_Type                                                       NaN
# Steering_Controls                                                       NaN
#
#                                                                      334996  \
# Unnamed: 0                                                           334996
# SalesID                                                             2348159
# SalePrice                                                             18000
# MachineID                                                           1663560
# ModelID                                                                4603
# datasource                                                              136
# auctioneerID                                                              1
# YearMade                                                               1994
# MachineHoursCurrentMeter                                                  0
# UsageBand                                                               NaN
# saledate                                                2008-04-10 00:00:00
# fiModelDesc                                                            310D
# fiBaseModel                                                             310
# fiSecondaryDesc                                                           D
# fiModelSeries                                                           NaN
# fiModelDescriptor                                                       NaN
# ProductSize                                                             NaN
# fiProductClassDesc        Backhoe Loader - 14.0 to 15.0 Ft Standard Digg...
# state                                                             Tennessee
# ProductGroup                                                             BL
# ProductGroupDesc                                            Backhoe Loaders
# Drive_System                                                Two Wheel Drive
# Enclosure                                                             OROPS
# Forks                                                   None or Unspecified
# Pad_Type                                                None or Unspecified
# Ride_Control                                                             No
# Stick                                                              Standard
# Transmission                                                       Standard
# Turbocharged                                            None or Unspecified
# Blade_Extension                                                         NaN
# Blade_Width                                                             NaN
# Enclosure_Type                                                          NaN
# Engine_Horsepower                                                       NaN
# Hydraulics                                                              NaN
# Pushblock                                                               NaN
# Ripper                                                                  NaN
# Scarifier                                                               NaN
# Tip_Control                                                             NaN
# Tire_Size                                                               NaN
# Coupler                                                                 NaN
# Coupler_System                                                          NaN
# Grouser_Tracks                                                          NaN
# Hydraulics_Flow                                                         NaN
# Track_Type                                                              NaN
# Undercarriage_Pad_Width                                                 NaN
# Stick_Length                                                            NaN
# Thumb                                                                   NaN
# Pattern_Changer                                                         NaN
# Grouser_Type                                                            NaN
# Backhoe_Mounting                                                        NaN
# Blade_Type                                                              NaN
# Travel_Controls                                                         NaN
# Differential_Type                                                       NaN
# Steering_Controls                                                       NaN
#
#                                                                      334997  \
# Unnamed: 0                                                           334997
# SalesID                                                             2348160
# SalePrice                                                             11500
# MachineID                                                           1650062
# ModelID                                                                4603
# datasource                                                              136
# auctioneerID                                                              4
# YearMade                                                               1994
# MachineHoursCurrentMeter                                                  0
# UsageBand                                                               NaN
# saledate                                                2010-02-08 00:00:00
# fiModelDesc                                                            310D
# fiBaseModel                                                             310
# fiSecondaryDesc                                                           D
# fiModelSeries                                                           NaN
# fiModelDescriptor                                                       NaN
# ProductSize                                                             NaN
# fiProductClassDesc        Backhoe Loader - 14.0 to 15.0 Ft Standard Digg...
# state                                                               Florida
# ProductGroup                                                             BL
# ProductGroupDesc                                            Backhoe Loaders
# Drive_System                                                Two Wheel Drive
# Enclosure                                                             OROPS
# Forks                                                   None or Unspecified
# Pad_Type                                                None or Unspecified
# Ride_Control                                                             No
# Stick                                                              Standard
# Transmission                                                       Standard
# Turbocharged                                            None or Unspecified
# Blade_Extension                                                         NaN
# Blade_Width                                                             NaN
# Enclosure_Type                                                          NaN
# Engine_Horsepower                                                       NaN
# Hydraulics                                                              NaN
# Pushblock                                                               NaN
# Ripper                                                                  NaN
# Scarifier                                                               NaN
# Tip_Control                                                             NaN
# Tire_Size                                                               NaN
# Coupler                                                                 NaN
# Coupler_System                                                          NaN
# Grouser_Tracks                                                          NaN
# Hydraulics_Flow                                                         NaN
# Track_Type                                                              NaN
# Undercarriage_Pad_Width                                                 NaN
# Stick_Length                                                            NaN
# Thumb                                                                   NaN
# Pattern_Changer                                                         NaN
# Grouser_Type                                                            NaN
# Backhoe_Mounting                                                        NaN
# Blade_Type                                                              NaN
# Travel_Controls                                                         NaN
# Differential_Type                                                       NaN
# Steering_Controls                                                       NaN
#
#                                                                      334998  \
# Unnamed: 0                                                           334998
# SalesID                                                             2348161
# SalePrice                                                             12000
# MachineID                                                           1663950
# ModelID                                                                4603
# datasource                                                              136
# auctioneerID                                                              1
# YearMade                                                               1994
# MachineHoursCurrentMeter                                                  0
# UsageBand                                                               NaN
# saledate                                                2007-09-26 00:00:00
# fiModelDesc                                                            310D
# fiBaseModel                                                             310
# fiSecondaryDesc                                                           D
# fiModelSeries                                                           NaN
# fiModelDescriptor                                                       NaN
# ProductSize                                                             NaN
# fiProductClassDesc        Backhoe Loader - 14.0 to 15.0 Ft Standard Digg...
# state                                                                 Texas
# ProductGroup                                                             BL
# ProductGroupDesc                                            Backhoe Loaders
# Drive_System                                                Two Wheel Drive
# Enclosure                                                             OROPS
# Forks                                                   None or Unspecified
# Pad_Type                                                None or Unspecified
# Ride_Control                                                             No
# Stick                                                              Standard
# Transmission                                                       Standard
# Turbocharged                                            None or Unspecified
# Blade_Extension                                                         NaN
# Blade_Width                                                             NaN
# Enclosure_Type                                                          NaN
# Engine_Horsepower                                                       NaN
# Hydraulics                                                              NaN
# Pushblock                                                               NaN
# Ripper                                                                  NaN
# Scarifier                                                               NaN
# Tip_Control                                                             NaN
# Tire_Size                                                               NaN
# Coupler                                                                 NaN
# Coupler_System                                                          NaN
# Grouser_Tracks                                                          NaN
# Hydraulics_Flow                                                         NaN
# Track_Type                                                              NaN
# Undercarriage_Pad_Width                                                 NaN
# Stick_Length                                                            NaN
# Thumb                                                                   NaN
# Pattern_Changer                                                         NaN
# Grouser_Type                                                            NaN
# Backhoe_Mounting                                                        NaN
# Blade_Type                                                              NaN
# Travel_Controls                                                         NaN
# Differential_Type                                                       NaN
# Steering_Controls                                                       NaN
#
#                                                                      334999
# Unnamed: 0                                                           334999
# SalesID                                                             2348162
# SalePrice                                                             11500
# MachineID                                                           1751542
# ModelID                                                                4603
# datasource                                                              136
# auctioneerID                                                              1
# YearMade                                                               1994
# MachineHoursCurrentMeter                                                  0
# UsageBand                                                               NaN
# saledate                                                2009-03-26 00:00:00
# fiModelDesc                                                            310D
# fiBaseModel                                                             310
# fiSecondaryDesc                                                           D
# fiModelSeries                                                           NaN
# fiModelDescriptor                                                       NaN
# ProductSize                                                             NaN
# fiProductClassDesc        Backhoe Loader - 14.0 to 15.0 Ft Standard Digg...
# state                                                               Georgia
# ProductGroup                                                             BL
# ProductGroupDesc                                            Backhoe Loaders
# Drive_System                                                Two Wheel Drive
# Enclosure                                                             OROPS
# Forks                                                   None or Unspecified
# Pad_Type                                                None or Unspecified
# Ride_Control                                                             No
# Stick                                                              Extended
# Transmission                                                       Standard
# Turbocharged                                            None or Unspecified
# Blade_Extension                                                         NaN
# Blade_Width                                                             NaN
# Enclosure_Type                                                          NaN
# Engine_Horsepower                                                       NaN
# Hydraulics                                                              NaN
# Pushblock                                                               NaN
# Ripper                                                                  NaN
# Scarifier                                                               NaN
# Tip_Control                                                             NaN
# Tire_Size                                                               NaN
# Coupler                                                                 NaN
# Coupler_System                                                          NaN
# Grouser_Tracks                                                          NaN
# Hydraulics_Flow                                                         NaN
# Track_Type                                                              NaN
# Undercarriage_Pad_Width                                                 NaN
# Stick_Length                                                            NaN
# Thumb                                                                   NaN
# Pattern_Changer                                                         NaN
# Grouser_Type                                                            NaN
# Backhoe_Mounting                                                        NaN
# Blade_Type                                                              NaN
# Travel_Controls                                                         NaN
# Differential_Type                                                       NaN
# Steering_Controls                                                       NaN

# %%
#take the log as the dataset will be evaluated using rmsle (root mean squared log error)
df_raw.SalePrice = np.log(df_raw.SalePrice)
df_raw.SalePrice
# Out:
# 0         2.406712
# 1         2.393413
# 2         2.220327
# 3         2.356923
# 4         2.230622
#             ...
# 334995    2.248414
# 334996    2.282191
# 334997    2.235387
# 334998    2.239929
# 334999    2.235387
# Name: SalePrice, Length: 335000, dtype: float64

# %%
# Using RandomForestRegressor
m = RandomForestRegressor(n_jobs = -1)
m.fit(df_raw.drop('SalePrice', axis = 1), df_raw.SalePrice)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-f0900c4b8077> in <module>
#       1 # Using RandomForestRegressor
#       2 m = RandomForestRegressor(n_jobs = -1)
# ----> 3 m.fit(df_raw.drop('SalePrice', axis = 1), df_raw.SalePrice)
#
# ~/opt/anaconda3/envs/BBFB/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     302             )
#     303         X, y = self._validate_data(X, y, multi_output=True,
# --> 304                                    accept_sparse="csc", dtype=DTYPE)
#     305         if sample_weight is not None:
#     306             sample_weight = _check_sample_weight(sample_weight, X)
#
# ~/opt/anaconda3/envs/BBFB/lib/python3.7/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ~/opt/anaconda3/envs/BBFB/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/opt/anaconda3/envs/BBFB/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     801                     ensure_min_samples=ensure_min_samples,
#     802                     ensure_min_features=ensure_min_features,
# --> 803                     estimator=estimator)
#     804     if multi_output:
#     805         y = check_array(y, accept_sparse='csr', force_all_finite=True,
#
# ~/opt/anaconda3/envs/BBFB/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/opt/anaconda3/envs/BBFB/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     597                     array = array.astype(dtype, casting="unsafe", copy=False)
#     598                 else:
# --> 599                     array = np.asarray(array, order=order, dtype=dtype)
#     600             except ComplexWarning:
#     601                 raise ValueError("Complex data not supported\n"
#
# ~/.local/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: 'Low'
